# %% [markdown]
# # Project Overview

# %%
# Customer Segmentation using KMeans Clustering
# This project groups customers based on income and spending behavior.

# %% [markdown]
# # Imprt Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab import files

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %% [markdown]
# # Load Dataset

# %%
uploaded = files.upload()

# %%
df = pd.read_csv("Mall_Customers.csv")
df.head()

# %%
df.info()

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# ## Feature Selection

# %%
X = df[["Annual Income (k$)", "Spending Score (1-100)"]]

# %%
plt.figure(figsize=(6,6))
sns.scatterplot(
    x="Annual Income (k$)",
    y="Spending Score (1-100)",
    data=df
)
plt.show()

# %% [markdown]
# ## Feature Scaling

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# # Elbow Method

# %%
wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, random_state=42, n_init=10)
    kmeans.fit(X_scaled)
    wcss.append(kmeans.inertia_)

# %%
plt.plot(range(1,11), wcss)
plt.xlabel("Number of Clusters")
plt.ylabel("WCSS")
plt.show()

# %% [markdown]
# # KMeans Clustering

# %%
kmeans = KMeans(n_clusters=5, random_state=42, n_init=10)
df["cluster"] = kmeans.fit_predict(X_scaled)

# %% [markdown]
# # Cluster Visualization

# %%
plt.figure(figsize=(6,6))

sns.scatterplot(
    x="Annual Income (k$)",
    y="Spending Score (1-100)",
    hue="cluster",
    palette="Set1",
    data=df
)

plt.title("Customer Segments")
plt.show()

# %% [markdown]
# # Cluster Analysis

# %%
df.groupby("cluster").mean(numeric_only=True)

# %% [markdown]
# # Business Insights

# %%
# Younger customers tend to spend more regardless of income.
# High income does not always imply high spending.
# Customer behavior depends on age and lifestyle patterns.

# %% [markdown]
# # Conclusion

# %%
# KMeans clustering successfully identified distinct customer groups that can help businesses improve marketing strategies and customer targeting.
